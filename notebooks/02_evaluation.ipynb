# %%
import pandas as pd
import seaborn as sns
import joblib
import os

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn import set_config; set_config(display='diagram')

from xgboost import XGBClassifier

# %%
from utils import load_data, evaluate, load_path_validation_data, load_path_preprocessor_and_model

# %%
def load_trained_artifacts():
    """
    Loads saved processor, model and pipeline
    """
    #Load artifacts from memory
    print("🔄 Loading components: preprocessor and model...")
    preprocessor_path, model_path = load_path_preprocessor_and_model()
    preprocessor = joblib.load(preprocessor_path)
    model = joblib.load(model_path)

    print("✅ Artifacts successfully loaded!")
    return preprocessor, model

# %%
preprocessor, model = load_trained_artifacts()
# Out:
# 🔄 Loading components: preprocessor and model...
# /Users/annamorgiel/code/soodabeh/retention-agent/notebooks/models/xgb_churn_preprocessor.pkl
# /Users/annamorgiel/code/soodabeh/retention-agent/notebooks/models/xgb_churn_model.pkl
# ✅ Artifacts successfully loaded!

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['AccountAge', 'MonthlyCharges',
#                                   'TotalCharges', 'ViewingHoursPerWeek',
#                                   'AverageViewingDuration',
#                                   'ContentDownloadsPerMonth', 'UserRating',
#                                   'SupportTicketsPerMonth', 'WatchlistSize']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore',
# ...

# %%
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
file_path_X, file_path_y = load_path_validation_data()
X_val = load_data(file_path_X)
y_val = load_data(file_path_y)

# %%
X_val.head()
# Out:
#    AccountAge  MonthlyCharges  TotalCharges SubscriptionType  \
# 0          31       18.871369    585.012434            Basic
# 1          34       17.339934    589.557749          Premium
# 2          88        5.321946    468.331228          Premium
# 3          37       15.836623    585.955056          Premium
# 4          94        8.746215    822.144229            Basic
#
#       PaymentMethod PaperlessBilling ContentType MultiDeviceAccess  \
# 0      Mailed check               No      Movies               Yes
# 1     Bank transfer               No        Both                No
# 2     Bank transfer               No    TV Shows               Yes
# 3  Electronic check              Yes        Both                No
# 4     Bank transfer              Yes      Movies                No
#
#   DeviceRegistered  ViewingHoursPerWeek  AverageViewingDuration  \
# 0         Computer            20.515996              154.972317
# ...

# %%
y_val.head()
# Out:
#    Churn
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0

# %%
evaluate(preprocessor, model, X_val, y_val)
# Out:
# ================ MODEL PERFORMANCE ================
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     39922
#            1       0.57      0.11      0.18      8836
#
#     accuracy                           0.82     48758
#    macro avg       0.70      0.54      0.54     48758
# weighted avg       0.79      0.82      0.77     48758
#
# ROC-AUC Score: 0.7466
# ============================================= =======
# (array([0, 0, 0, ..., 0, 0, 0], shape=(48758,)),
#  array([0.346462  , 0.2498818 , 0.09865487, ..., 0.37843138, 0.3671446 ,
#         0.12476036], shape=(48758,), dtype=float32))
