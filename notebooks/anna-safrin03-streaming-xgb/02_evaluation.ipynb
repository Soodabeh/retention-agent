# %%
import pandas as pd
import seaborn as sns
import joblib
import os

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn import set_config; set_config(display='diagram')

from xgboost import XGBClassifier

# %%
from src.utils import load_data, evaluate

# %%
def load_trained_artifacts():
    """
    Loads saved processor, model and pipeline
    """
    #Load artifacts from memory
    print("🔄 Loading components: preprocessor and model...")

    model = joblib.load(os.environ["MODEL_PATH"]+ os.environ["MODEL_NAME_XGB"])
    preprocessor = joblib.load(os.environ["MODEL_PATH"]+os.environ["MODEL_NAME_PREPROCESSOR"])

    print("✅ Artifacts successfully loaded!")
    return preprocessor, model

# %%
preprocessor, model = load_trained_artifacts()
# Out:
# 🔄 Loading components: preprocessor and model...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 preprocessor, model = load_trained_artifacts()
#
# Cell In[3], line 9, in load_trained_artifacts()
#       6 print("🔄 Loading components: preprocessor and model...")
#       8 model = joblib.load(os.environ["MODEL_PATH"]+ os.environ["MODEL_NAME_XGB"])
# ----> 9 preprocessor = joblib.load(os.environ["MODEL_PATH"]+os.environ["MODEL_NAME_PREPROCESSOR"])
#      11 print("✅ Artifacts successfully loaded!")
#      12 return preprocessor, model
#
# File ~/.pyenv/versions/3.10.6/envs/retention-agent/lib/python3.10/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
# ...

# %%
X_val = load_data(os.environ["VALIDATION_DATA_PATH"]+ os.environ["VALIDATION_DATA_X"])
y_val = load_data(os.environ["VALIDATION_DATA_PATH"]+ os.environ["VALIDATION_DATA_Y"])

# %%
X_val.head()

# %%
y_val.head()

# %%
evaluate(preprocessor, model, X_val, y_val)
